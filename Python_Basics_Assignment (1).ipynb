# %% [markdown]
# 1. Explain the key features of Python that make it a popular choice for programming.
#       => Readability: One of the standout features of Python is its clear and straightforward. This makes it incredibly beginner - friendly, allowing new programmers to pick it up quickly.
#       => Simplicity: The way Python uses to define code blocks not only enhances readability but also promotes good coding practices, making it easier to maintain and collaborate.
#       => Versatile: Python is a versatile language that supports multiple programming paradigms, including procedural, object-oriented, and functional programming.
#      => Cross Platform: Python runs on various operating systems, including Windows, mac OS, and Linux, making it versatile.
#      =>Community Support: Python has a large and active community, which means plenty of resources, tutorials, and third-party modules are available.
#      =>Dynamically in nature: No need to declare the type of a variable when you create one. The type is determined at runtime.
#
# 2.  Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#      => In Python, predefined words, also known as keywords, serve as the fundamental building blocks of the language. These keywords have specific meanings and purposes, and they cannot be used as identifiers (such as variable names, function names, etc.). Keywords help define the structure and control flow of a program. One of the key roles of these predefined words is to control the flow of execution in a program.
#
# . Role of Predefined Keywords
#    a. Control Flow: Keywords like if, else, elif, for and while are used to control the flow of execution in a program, allowing for conditional execution and looping.
#    b. Keywords such as def. and class are used to define functions and classes, respectively, which are fundamental building blocks in Python programming.
#  	 c.Data management: Keywords like import and from are used to include external modules and libraries, enabling code reuse and modular programming.
# 	 d.Exception Handling: Keywords like try, except, finally, and raise are used to handle exceptions and errors gracefully.
# 	 e.Context Management: The with keyword is used for resource management, ensuring that resources are properly acquired and release
#
#   For example, consider the following Python program that uses several predefined words:
#  def check_even_odd(number):
#   if number % 2 == 0:
#   return "Even"
# else: return "Odd"
#
# # Using a loop to check numbers from 1 to 10
# for i in range(1, 11):
#  print (f"{i} is {check_even_odd(i)}")
#
#  In this program:
#  - The def keyword is used to define the function check_even_odd.
#  - The if and else keywords are used to create a conditional statement that checks whether the number is even or odd.
# - The for keyword is used to iterate through numbers from 1 to 10 using a loop.
#
#
# 3. Compare and contrast mutable and immutable objects in Python with examples.
# In Python, objects can be classified as mutable or immutable based on whether their state can be modified after they are created.
# *Mutable Objects: - Mutable objects are those whose state or value can be changed after they are created. This means you can modify the contents of the object without changing its identity. - Examples of mutable objects in Python include lists, dictionaries, and sets.
#  Immutable Objects: - Immutable objects, on the other hand, cannot be changed after they are created. Any modification to an immutable object results in the creation of a new object rather than altering the original one. - Examples of immutable objects in Python include strings, tuples, and frozensets.
#  Comparison
# 1. Modification: - Mutable: The contents can be changed. For example, you can add, remove, or update elements in a list.
# - Immutable: The contents cannot be changed. Any attempt to modify an object results in a new object.
# 2. Identity: - Mutable: The identity of the object remains the same even after modifications.
# - Immutable: The identity of the object changes when a new object is created due to modifications.
#  3. **Performance: - Mutable: Generally, more efficient for operations involving frequent modifications since they do not require creating new objects.
#  - Immutable: May be less efficient for extensive modifications because new objects need to be created.
#
#  Examples
#  Creating a mutable list my_list = [1, 2, 3]
#    print("Original List:", my_list)
#  Modifying the list my_list.append(4)
#     print("Modified List:", my_list)
#
# Output:  Original List: [1, 2, 3]
# Modified List: [1, 2, 3, 4]
#
#  Immutable Example
#
#  Creating an immutable string
#  my_string = "Hello" print("Original String:", my_string)
#
#  # Attempting to modify the string new_string = my_string.replace("H", "J")
#  print("Modified String:", new_string)
#  print("Original String after modification attempt:", my_string)
#
# Output:  Original String: Hello
# Modified String:  Jello
#  Original String after modification attempt: Hello
#
# 4. Discuss the different types of operators in Python and provide examples of how they are used.
#  In Python, operators are special symbols that perform operations on variables and values. Python supports several types of operators, each serving a different purpose. Here’s a breakdown of the different types of operators in Python, along with examples of how they are used:
#
# In Python, operations can be categorized into several types based on the nature of the tasks they perform. Here are the main types of operations along with examples:
# 1. Arithmetic Operations*: These are fundamental operations used to perform mathematical calculations.
# •	Addition (+): Adds two numbers.
#  Example:
#                 result = 5 + 3 result is 8
#
# •	Subtraction (-): Subtracts one number from another.
#  Example:
#                    result = 10 - 4 result is 6
# •	Multiplication (*): Multiplies two numbers.
# Example:
#               result = 7 * 6 result is 42
# •	  Division (/): Divides one number by another.
#  Example:
#                 result = 20 / 4   result is 5.0
# Floor Division (//): Divides and returns the largest integer less than or equal to the result.
# Example:
#           result = 20 // 3 # result is 6
# •	Modulus (%): Returns the remainder of the division.
# Example:
#                 python result = 11 % 3 # result is 2
# Exponentiation (**): Raises the first operand to the power of the second.
#                Example:
#                               python result = 2 ** 3 # result is 8
# 2. Comparison Operators
# Comparison operators are used to compare two values and return a Boolean result (True or False).
# •	Equal to (==): Checks if two operands are equal.
# •	Example:  is_equal = (5 == 5) # is equal is True
# •	Not equal to (!=): Checks if two operands are not equal.
#  is_not_equal = (5 != 3) # is_not_equal is True
# •	Greater than (>): Checks if the left operand is greater than the right.
#  Example:  is_greater = (7 > 4) # is_greater is True
# •	Less than (<): Checks if the left operand is less than the right.
# Example:  is_less=(3<5)  # is _less is True
# •	Greater than or equal to (>=): Checks if the left operand is greater than or equal to the right.
# Example: is_greater_equal = (5 >= 5) # is_greater_equal is True
# •	Less than or equal to (<=): Checks if the left operand is less than or equal to the right.
#
# 3. Logical Operators
# Logical operators are used to combine conditional statements.
#       AND (and): Returns True if both operands are true.
#       Example = (a > 5 and b < 10)  # result is True
#   	OR (or): Returns True if at least one of the operands is true.
#   	Example = (a > 15 or b < 10)  # result is True
#     NOT (not): Reverses the logical state of its operand.
# Example = not (a > 5)  # result is False
#
#
#     4. Assignment Operators
#     These operators are used to assign values to variables.
#       Assignment (=): Assigns the right operand to the left operand.
#      Example : c = a + b  # c is 15
#
#  	 Add and assign (+=): Adds the right operand to the left operand and assigns the result to the left operand.
#
#   Example : c += 5  # c is now 20
#   Subtract and assign (-=): Subtracts the right operand from the left operand and assigns the result to the left operand.
#   Example : c += 5  # c is now 20
#
#   Multiply and assign (*=): Multiplies the left operand by the right operand and assigns the result to the left operand.
#   Example : c *= 2  # c is now 30
#
#   Divide and assign (/=): Divides the left operand by the right operand and assigns the result to the left operand.
#   Example : c /= 3  # c is now 10.0
#
# 5.  Explain the concept of type casting in Python with examples0
#   Type casting in Python refers to the conversion of a variable from one data type to another. This process is essential when you want to perform operations that require different data types to be compatible with each other. Python provides several built-in functions for type casting, including int(), float(), str(), and list().
#
#   Example of Type Casting Consider the following example where we need to convert a string that represents a number into an integer so that we can perform arithmetic operations:
#    String representation of a number
#            num_str = "10"
#   Convert the string to an integer
#                  num_int = int(num_str)
#
#    Perform an arithmetic operation
#         result = num_int + 5
#    Perform an arithmetic operation result = num_int + 5
#    print("Result of the addition:", result) # Output: Result of the addition : 15
#
#    In this example, the string num_str is converted into an integer using the int() function. After the conversion, we can successfully add 5 to it, yielding a result of 15.
#    Another common scenario involves converting an integer to a string for concatenation.
#
#    Integer
#          num_int = 20
#      Convert the integer to a string
#         num_str = str(num_int)
#    Concatenate with another string
#          result_str = "The number is: " + num_str
#      print(result_str) # Output: The number is: 20.
#
# 6. How do conditional statements work in Python? Illustrate with examples
#
#   =>Conditional statements in Python allow you to execute certain blocks of code based on whether a condition is true or false. The primary conditional statements in Python are if, elif, and else. Here's how they work:
#
#   Basic Structure
#   1.if statement: This checks a condition and executes a block of code if the condition is true.
#
#  2.elif statement: This stands for "else if" and allows you to check multiple conditions. It is executed if the previous if or elif conditions are false.
#
#  3.else statement: This is executed if none of the preceding conditions are true.
#
# How Conditional Statements Work
#  1.Evaluation of Conditions: When the program reaches a conditional statement, it evaluates the condition(s) in the order they are written.
# 2.Execution of Code Blocks:
#   	If the condition in the if statement is true, the corresponding block of code is executed, and the rest of the conditions are skipped.
#  	If the if condition is false, the program checks the next elif condition (if any). If that condition is true, its block of code is executed.
#   If none of the if or elif conditions are true, the else block (if present) is executed.
#
#   Example 1: Simple if-else
#
#    age = 18
#
#   if age >= 18:
#      print("You are an adult.")
#   else:
#       print("You are a minor.")
#
#   Example 2: Using elif
#   score = 85
#
#   if score >= 90:
#    print("Grade: A")
#   elif score >= 80:
#    print("Grade: B")
#   elif score >= 70:
#    print("Grade: C")
#   else:
#    print("Grade: D or F")
#
#   Example 3: Multiple Conditions
#   temperature = 20
#   is_raining = False
#
#   if temperature > 15 and not is_raining:
#      print("It's a nice day for a picnic!")
#   elif temperature > 15 and is_raining:
#    print("It's warm, but you might want an umbrella.")
#   else:
#      print("It's not a good day for a picnic.")
#
#   Example 4: Nested Conditional Statements
#   num = 10
#    if num > 0:
#      print("The number is positive.")
#       if num % 2 == 0:
#        print("The number is even.")
#      else:
#      print("The number is odd.")
#    else:
#    print("The number is not positive.")
#
# 7. Describe the different types of loops in Python and their use cases with examples.
#   =>In Python, there are primarily two types of loops used for iteration: for loops and while loops. Each serves different purposes and has its own syntax and use cases. Here’s a detailed description of each type:
# 1.	 For Loops A for loop is used to iterate over a sequence (like a list, tuple, dictionary, set, or string). This loop is particularly useful when the number of iterations is known beforehand or when you need to iterate over items in a collection.
# Example:
#        fruits = ['apple','banana','cherry']
#        for fruit in fruits:
#            print(fruit)
#
# 2. While Loops A while loop repeatedly executes a block of code as long as a specified condition is true. This type of loop is useful when the number of iterations is not known in advance and depends on a condition being met.
#  Example:
#   count = 0
# while count < 5:
#  print(count)
# count += 1
#
# 4.	Nested Loops A nested loop is a loop inside another loop. This is useful for scenarios where you need to perform operations on multi-dimensional data structures, such as lists of lists or matrices. *Example:
#  for i in range(3): # Outer loop
#  for j in range(2): # Inner loop
#    print(f'i={i}, j={j}')
